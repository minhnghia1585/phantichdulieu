# %% [markdown]
# <a href="https://colab.research.google.com/github/minhnghia1585/phantichdulieu/blob/main/lab04_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
datatitanic = pd.read_csv("https://raw.githubusercontent.com/huynhhoc/phantichdulieu/main/Data/titanic_disaster.csv")
datatitanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
def sex(x_df):
    mapping={'Male':'M', 'Female':'F'}
    x_df['Sex']=x_df['Sex'].map(mapping)
    return x_df
datatitanic=(datatitanic.pipe(sex))
datatitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  NaN  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  NaN  38.0      1
# 2                               Heikkinen, Miss. Laina  NaN  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  NaN  35.0      1
# 4                             Allen, Mr. William Henry  NaN  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
import seaborn as sns
sns.boxplot(y='Age', x='Pclass', data = datatitanic)

# %%
import seaborn as sns
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
sns.heatmap(patientheartrate.isna(), 
            yticklabels=False, 
            cbar=True, 
            cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-7e081c7d8e02> in <module>()
#       2 get_ipython().magic('matplotlib inline')
#       3 get_ipython().magic("config InlineBackend.figure_format = 'svg'")
# ----> 4 sns.heatmap(patientheartrate.isna(),
#       5             yticklabels=False,
#       6             cbar=True,
#
# NameError: name 'patientheartrate' is not defined

# %%
tidisater5["Age"][tidisater5["Pclass"] == 1] = tidisater5["Age"][tidisater5["Pclass"] == 1].fillna(tidisater5["Age"][tidisater5["Pclass"] == 1].median(), inplace = False)
